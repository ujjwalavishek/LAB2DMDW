# %%
import numpy as np

# %%
from scipy import stats

# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\ujjwal abhishek\Downloads\archive\covid_impact_on_airport_traffic.csv")
dataset
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-07-05      1.0                Kingsford Smith
# 1                Daily  2020-05-28      1.0                Kingsford Smith
# 2                Daily  2020-05-07      1.0                Kingsford Smith
# 3                Daily  2020-06-24      1.0                Kingsford Smith
# 4                Daily  2020-08-05      1.0                Kingsford Smith
# 5                Daily  2020-10-16      1.0                Kingsford Smith
# 6                Daily  2020-06-01      1.0                Kingsford Smith
# 7                Daily  2020-06-18      1.0                Kingsford Smith
# 8                Daily  2020-09-15      1.0                Kingsford Smith
# 9                Daily  2020-08-10      1.0                Kingsford Smith
# 10               Daily  2020-08-30      1.0                Kingsford Smith
# ...

# %%
dataset.head()
# Out:
#   AggregationMethod        Date  Version      AirportName  PercentOfBaseline  \
# 0             Daily  2020-07-05      1.0  Kingsford Smith                 52
# 1             Daily  2020-05-28      1.0  Kingsford Smith                 61
# 2             Daily  2020-05-07      1.0  Kingsford Smith                 62
# 3             Daily  2020-06-24      1.0  Kingsford Smith                 58
# 4             Daily  2020-08-05      1.0  Kingsford Smith                 20
#
#                                     Centroid    City            State  \
# 0  POINT(151.180087713813 -33.9459774986125)  Sydney  New South Wales
# 1  POINT(151.180087713813 -33.9459774986125)  Sydney  New South Wales
# 2  POINT(151.180087713813 -33.9459774986125)  Sydney  New South Wales
# 3  POINT(151.180087713813 -33.9459774986125)  Sydney  New South Wales
# 4  POINT(151.180087713813 -33.9459774986125)  Sydney  New South Wales
#
#   ISO_3166_2    Country                                          Geography
# ...

# %%
dataset.shape
# Out:
# (5936, 11)

# %%
dataset.columns
# Out:
# Index(['AggregationMethod', 'Date', 'Version', 'AirportName',
#        'PercentOfBaseline', 'Centroid', 'City', 'State', 'ISO_3166_2',
#        'Country', 'Geography'],
#       dtype='object')

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-07-05      1.0                Kingsford Smith
# 1                Daily  2020-05-28      1.0                Kingsford Smith
# 2                Daily  2020-05-07      1.0                Kingsford Smith
# 3                Daily  2020-06-24      1.0                Kingsford Smith
# 4                Daily  2020-08-05      1.0                Kingsford Smith
# 5                Daily  2020-10-16      1.0                Kingsford Smith
# 6                Daily  2020-06-01      1.0                Kingsford Smith
# 7                Daily  2020-06-18      1.0                Kingsford Smith
# 8                Daily  2020-09-15      1.0                Kingsford Smith
# 9                Daily  2020-08-10      1.0                Kingsford Smith
# 10               Daily  2020-08-30      1.0                Kingsford Smith
# ...

# %%
dataset.describe()
# Out:
#        Version  PercentOfBaseline
# count   5936.0        5936.000000
# mean       1.0          65.581705
# std        0.0          21.985070
# min        1.0           0.000000
# 25%        1.0          52.000000
# 50%        1.0          66.000000
# 75%        1.0          82.000000
# max        1.0         100.000000

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum()
# Out:
# AggregationMethod    0
# Date                 0
# Version              0
# AirportName          0
# PercentOfBaseline    0
# Centroid             0
# City                 0
# State                0
# ISO_3166_2           0
# Country              0
# Geography            0
# dtype: int64
